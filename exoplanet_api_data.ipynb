# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json

# %%
# Opening JSON file
data = open("Resources/microlensing.json",)
data
# Out:
# <_io.TextIOWrapper name='Resources/microlensing.json' mode='r' encoding='cp1252'>

# %%
data_file = json.load(data)

# %%
# Print the json (pretty printed)
print(json.dumps(data_file, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "decstr": "-28d12m04.00s",
#         "htmllink": "<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....160...17H/abstract target=ref>Han et al. 2020</a>",
#         "ml_angstlax": 2.5,
#         "ml_angstlaxerr1": 0.029,
#         "ml_angstlaxerr2": -0.029,
#         "ml_angstlaxlim": 0,
#         "ml_dists": 8000.0,
#         "ml_distserr1": null,
#         "ml_distserr2": null,
#         "ml_distslim": 0,
#         "ml_magibl": null,
#         "ml_magiblerr1": null,
#         "ml_magiblerr2": null,
#         "ml_magibllim": null,
#         "ml_magis": 20.68,
#         "ml_magiserr1": 0.01,
#         "ml_magiserr2": -0.01,
#         "ml_magislim": 0,
#         "ml_massratio": 19.1,
#         "ml_massratioerr1": 9.2,
#         "ml_massratioerr2": -9.2,
#         "ml_massratiolim": 0,
#         "ml_modeldef": 0,
#         "ml_pmrells": 5.7,
#         "ml_pmrellserr1": 0.46,
#         "ml_pmrellserr2": -0.46,
#         "ml_pmrellslim": 0,
# ...
