# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json

# %% [markdown]
# # Extract Data:

# %% [markdown]
# data = open("Resources/microlensing.json",)
# data

# %%
data = open("Resources/microlensing.json",)

# %%
data_file = json.load(data)

# %% [markdown]
# data_dump_file = json.dumps(data_file, indent=4, sort_keys=True)
# data_dump_file

# %%
data_dump_file = json.dumps(data_file, indent=4, sort_keys=True)

# %%
exoplanet_df = pd.read_json(data_dump_file)
exoplanet_df
# Out:
#             decstr                                           htmllink  \
# 0    -28d12m04.00s  <a refstr=HAN_ET_AL__2020 href=https://ui.adsa...
# 1    -29d23m53.66s  <a refstr=SUMI_ET_AL__2016 href=https://ui.ads...
# 2    -28d12m04.00s  <a refstr=HAN_ET_AL__2020 href=https://ui.adsa...
# 3       -30d22m38s  <a refstr=BEAULIEU_ET_AL__2006 href=https://ui...
# 4     -29d43m53.7s  <a refstr=KOSHIMOTO_ET_AL__2017 href=https://u...
# ..             ...                                                ...
# 314   -30d28m16.2s  <a refstr=POLESKI_ET_AL__2014 href=https://ui....
# 315   -28d39m39.2s  <a refstr=SHIN_ET_AL__2016 href=https://ui.ads...
# 316   +24d47m55.5s  <a refstr=NUCITA_ET_AL__2018 href=https://ui.a...
# 317  -26d01m54.48s  <a refstr=HWANG_ET_AL__2019 href=https://ui.ad...
# 318   -29d11m56.7s  <a refstr=JUNG_ET_AL__2019 href=https://ui.ads...
#
#      ml_angstlax  ml_angstlaxerr1  ml_angstlaxerr2  ml_angstlaxlim  ml_dists  \
# ...

# %%
# Save Data to csv
exoplanet_df.to_csv("exoplanet.csv", index = None)
